# %% [markdown]
# # Data Understanding

# %%
# import relevant libaries 
import numpy as np 
import pandas as pd 

# Data Visualization
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/Gender_StatsData.csv")
df.head(n=5)
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  A woman can apply for a passport in the same w...  SG.APL.PSPT.EQ   NaN
# 1  A woman can be head of household in the same w...  SG.HLD.HEAD.EQ   NaN
# 2  A woman can choose where to live in the same w...  SG.LOC.LIVE.EQ   NaN
# 3  A woman can get a job in the same way as a man...  SG.GET.JOBS.EQ   NaN
# 4  A woman can obtain a judgment of divorce in th...  SG.OBT.DVRC.EQ   NaN
#
#    1961  1962  1963  1964  1965  ...  2012  2013  2014  2015  2016  2017  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
df.shape
# Out:
# (164112, 66)

# %%
df['Indicator Name'].unique()
# Out:
# array(['A woman can apply for a passport in the same way as a man (1=yes; 0=no)',
#        'A woman can be head of household in the same way as a man (1=yes; 0=no)',
#        'A woman can choose where to live in the same way as a man (1=yes; 0=no)',
#        'A woman can get a job in the same way as a man (1=yes; 0=no)',
#        'A woman can obtain a judgment of divorce in the same way as a man (1=yes; 0=no)',
#        'A woman can open a bank account in the same way as a man (1=yes; 0=no)',
#        'A woman can register a business in the same way as a man (1=yes; 0=no)',
#        'A woman can sign a contract in the same way as a man (1=yes; 0=no)',
#        'A woman can travel outside her home in the same way as a man (1=yes; 0=no)',
#        'A woman can travel outside the country in the same way as a man (1=yes; 0=no)',
#        'A woman has the same rights to remarry as a man (1=yes; 0=no)',
#        'Access to anti-retroviral drugs, female (%)',
# ...

# %%
df[df['Indicator Name'] ==  'Female share of graduates in Information and Communication Technologies programmes, tertiary (%)'].head()
# Out:
#                         Country Name Country Code  \
# 138                       Arab World          ARB
# 762           Caribbean small states          CSS
# 1386  Central Europe and the Baltics          CEB
# 2010      Early-demographic dividend          EAR
# 2634             East Asia & Pacific          EAS
#
#                                          Indicator Name    Indicator Code  \
# 138   Female share of graduates in Information and C...  UIS.FGP.5T8.F600
# 762   Female share of graduates in Information and C...  UIS.FGP.5T8.F600
# 1386  Female share of graduates in Information and C...  UIS.FGP.5T8.F600
# 2010  Female share of graduates in Information and C...  UIS.FGP.5T8.F600
# 2634  Female share of graduates in Information and C...  UIS.FGP.5T8.F600
#
#       1960  1961  1962  1963  1964  1965  ...  2012  2013  2014  2015  2016  \
# 138    NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# ...

# %%
df_women = df.loc[df['Indicator Name'].str.contains("women", case=False)]
df_women['Indicator Name'].unique()
# Out:
# array(['Adolescent fertility rate (births per 1,000 women ages 15-19)',
#        'Contraceptive prevalence, any methods (% of women ages 15-49)',
#        'Contraceptive prevalence, modern methods (% of women ages 15-49)',
#        "Decision maker about a woman's own health care: mainly husband (% of women age 15-49)",
#        "Decision maker about a woman's own health care: mainly wife (% of women age 15-49)",
#        "Decision maker about a woman's own health care: other (% of women age 15-49)",
#        "Decision maker about a woman's own health care: someone else (% of women age 15-49)",
#        "Decision maker about a woman's own health care: wife and husband jointly (% of women age 15-49)",
#        "Decision maker about a woman's visits to her family or relatives: mainly husband (% of women age 15-49)",
#        "Decision maker about a woman's visits to her family or relatives: mainly wife (% of women age 15-49)",
# ...

# %%
df_female = df.loc[df['Indicator Name'].str.contains("female", case=False)]
df_female['Indicator Name'].unique()
# Out:
# array(['Access to anti-retroviral drugs, female (%)',
#        'Account ownership at a financial institution or with a mobile-money-service provider, female (% of population ages 15+)',
#        'Adjusted net enrollment rate, primary, female (% of primary school age children)',
#        'Age at first marriage, female',
#        'Age population, age 0, female, interpolated',
#        'Age population, age 01, female, interpolated',
#        'Age population, age 02, female, interpolated',
#        'Age population, age 03, female, interpolated',
#        'Age population, age 04, female, interpolated',
#        'Age population, age 05, female, interpolated',
#        'Cause of death, by communicable diseases, ages 15-34, female (% of relevant age group)',
#        'Cause of death, by communicable diseases, ages 35-59, female (% of relevant age group)',
#        'Cause of death, by injury, ages 15-34, female  (% of relevant age group)',
# ...

# %%
df[df['Indicator Name'] == 'Female migrants (% of international migrant stock)']
# Out:
#                                              Country Name Country Code  \
# 126                                            Arab World          ARB
# 750                                Caribbean small states          CSS
# 1374                       Central Europe and the Baltics          CEB
# 1998                           Early-demographic dividend          EAR
# 2622                                  East Asia & Pacific          EAS
# 3246          East Asia & Pacific (excluding high income)          EAP
# 3870                     East Asia & Pacific (IDA & IBRD)          TEA
# 4494                                            Euro area          EMU
# 5118                                Europe & Central Asia          ECS
# 5742        Europe & Central Asia (excluding high income)          ECA
# 6366                   Europe & Central Asia (IDA & IBRD)          TEC
# 6990                                       European Union          EUU
# ...

# %%
gii = pd.read_csv('data/Gender Inequality Index (GII).csv', skiprows=5, error_bad_lines=False, encoding = 'unicode_escape')
gii.head()
# Out:
#   HDI Rank       Country   1995 Unnamed: 3   2000  Unnamed: 5   2005  \
# 0      169   Afghanistan     ..        NaN     ..         NaN  0.745
# 1       69       Albania     ..        NaN  0.334         NaN  0.306
# 2       91       Algeria  0.682          a  0.624         NaN  0.552
# 3      148        Angola     ..        NaN     ..         NaN     ..
# 4       46     Argentina  0.427          a  0.417         NaN  0.372
#
#    Unnamed: 7   2010  Unnamed: 9  ...   2015  Unnamed: 19   2016  Unnamed: 21  \
# 0         NaN  0.751         NaN  ...  0.702          NaN  0.690          NaN
# 1         NaN  0.242         NaN  ...  0.207          NaN  0.205          NaN
# 2         NaN  0.507         NaN  ...  0.427          NaN  0.425          NaN
# 3         NaN     ..         NaN  ...  0.534          NaN  0.531          NaN
# 4         NaN  0.358         NaN  ...     ..          NaN  0.338          NaN
#
#     2017  Unnamed: 23   2018  Unnamed: 25   2019  Unnamed: 27
# ...

# %%
cols = ['HDI Rank', 'Country', '1995', '2000', '2005', '2010', '2011', '2012', '2013', '2014','2015', '2016', '2017', '2018', '2019']
gii[cols]
# Out:
#                                               HDI Rank  \
# 0                                                  169
# 1                                                   69
# 2                                                   91
# 3                                                  148
# 4                                                   46
# 5                                                   81
# 6                                                    8
# 7                                                   18
# 8                                                   88
# 9                                                   58
# 10                                                  42
# 11                                                 133
# 12                                                  58
# 13                                                  53
# 14                                                  14
# 15                                                 110
# ...
