# %% [markdown]
# # Exploratory Data Analysis

# %%
# import relevant libaries 
import numpy as np 
import pandas as pd 

# Data Visualization
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
stem = pd.read_csv('data/stem_female.csv')

# %%
stem.head()
# Out:
#      Country Name Country Code  \
# 0     Afghanistan          AFG
# 1         Albania          ALB
# 2         Algeria          DZA
# 3  American Samoa          ASM
# 4         Andorra          AND
#
#                                       Indicator Name    Indicator Code  1999  \
# 0  Female share of graduates in Information and C...  UIS.FGP.5T8.F600   NaN
# 1  Female share of graduates in Information and C...  UIS.FGP.5T8.F600   NaN
# 2  Female share of graduates in Information and C...  UIS.FGP.5T8.F600   NaN
# 3  Female share of graduates in Information and C...  UIS.FGP.5T8.F600   NaN
# 4  Female share of graduates in Information and C...  UIS.FGP.5T8.F600   NaN
#
#        2000  2001  2002      2003      2004  ...      2009      2010  \
# 0       NaN   NaN   NaN       NaN       NaN  ...       NaN       NaN
# 1  45.45455   NaN   NaN  67.85714       NaN  ...       NaN       NaN
# 2  45.45455   NaN   NaN  67.85714       NaN  ...  47.20217  48.80532
# ...

# %%
stem.shape
# Out:
# (217, 24)

# %%
stem.isna().sum()
# Out:
# Country Name       0
# Country Code       0
# Indicator Name     0
# Indicator Code     0
# 1999              10
# 2000               1
# 2001              18
# 2002               4
# 2003               1
# 2004               4
# 2005               4
# 2006               4
# 2007               2
# 2008               4
# 2009               2
# 2010               2
# 2011               1
# 2012               4
# 2013              10
# 2014              10
# 2015               1
# 2016               1
# 2017               1
# 2018               1
# dtype: int64

# %%
stem.index = stem['Country Name']

# %%
stem.head()
# Out:
#                   Country Name Country Code  \
# Country Name
# Afghanistan        Afghanistan          AFG
# Albania                Albania          ALB
# Algeria                Algeria          DZA
# American Samoa  American Samoa          ASM
# Andorra                Andorra          AND
#
#                                                    Indicator Name  \
# Country Name
# Afghanistan     Female share of graduates in Information and C...
# Albania         Female share of graduates in Information and C...
# Algeria         Female share of graduates in Information and C...
# American Samoa  Female share of graduates in Information and C...
# Andorra         Female share of graduates in Information and C...
#
#                   Indicator Code  1999      2000  2001  2002      2003  \
# Country Name
# Afghanistan     UIS.FGP.5T8.F600   NaN       NaN   NaN   NaN       NaN
# Albania         UIS.FGP.5T8.F600   NaN  45.45455   NaN   NaN  67.85714
# ...

# %%
stem = stem.drop(['Country Name', 'Country Code', 'Indicator Name',
       'Indicator Code'], axis = 1)

# %%
stem[['2015', '2016', '2017']].head()
# Out:
#                     2015       2016       2017
# Country Name
# Afghanistan          NaN        NaN        NaN
# Albania         49.20728   46.77419   46.48218
# Algeria         51.76786   54.27659   46.48218
# American Samoa  51.76786   54.27659   46.48218
# Andorra         51.76786  100.00000  100.00000

# %%
pd.DataFrame(stem.median(axis = 1).sort_values(ascending = False))
# Out:
#                                0
# Country Name
# Brunei Darussalam      52.704450
# Panama                 49.787080
# Philippines            49.787080
# Peru                   49.787080
# Paraguay               49.787080
# Papua New Guinea       49.787080
# Algeria                48.390025
# American Samoa         48.390025
# Albania                46.482180
# Yemen, Rep.            46.289445
# West Bank and Gaza     46.289445
# Zambia                 46.289445
# Saudi Arabia           46.155775
# Senegal                46.155775
# Cabo Verde             45.747785
# Burkina Faso           45.747785
# Bulgaria               45.747785
# Burundi                45.747785
# Zimbabwe               44.500760
# Kyrgyz Republic        43.576830
# Angola                 41.707210
# Lao PDR                41.243625
# Mali                   41.053615
# Maldives               41.053615
# Malaysia               41.053615
# Qatar                  40.089285
# Andorra                39.393940
# ...

# %%
top_20 = pd.DataFrame(stem[['2015','2016','2017']].mean(axis = 1).sort_values(ascending = False)[:20], columns = ['central'])
bottom_20 = pd.DataFrame(stem[['2015','2016','2017']].mean(axis = 1).sort_values(ascending = True)[:20], columns = ['central'])
all_ = pd.DataFrame(stem[['2015','2016','2017']].mean(axis = 1).sort_values(ascending = False), columns = ['central'])

# %%
bottom_20
# Out:
#                           central
# Country Name
# Belgium                  7.773607
# Eritrea                  8.660843
# Gibraltar                9.679677
# Ghana                    9.679677
# Switzerland              9.993173
# Belize                  11.651343
# China                   12.744227
# Chile                   12.744227
# Spain                   13.821360
# Lithuania               14.096113
# Bolivia                 14.431030
# Bhutan                  14.431030
# Bermuda                 14.431030
# British Virgin Islands  14.729573
# Brazil                  14.729573
# Czech Republic          14.773753
# Luxembourg              15.615470
# Macao SAR, China        15.784390
# Norway                  15.829333
# Austria                 16.569363

# %%
plt.figure(figsize=(12, 8))
splot=sns.barplot(y = top_20.index, x = 'central', data=top_20, color="gold")
plt.xlabel("", size=14)
plt.xticks([])
plt.ylabel("Country", size=14)
plt.title('Share of Female STEM graduates by Country (Top 20)')
for rect in splot.patches:
    width = rect.get_width()
    plt.text(0.975*rect.get_width(), rect.get_y()+0.5*rect.get_height(),
             '%d' % int(width),
             ha='center', va='center')
# plt.bar_label(splot.containers[0],size=16,label_type='center')
# plt.savefig("share_of_female_STEM_graduates_country_20.png")

# %%
plt.figure(figsize=(12, 8))
splot=sns.barplot(y = bottom_20.index, x = 'central', data=bottom_20, color="gold")
plt.xlabel("", size=14)
plt.xticks([])
plt.ylabel("Country", size=14)
plt.title('Share of female STEM graduates by Country (Bottom 20)')
for rect in splot.patches:
    width = rect.get_width()
    plt.text(0.975*rect.get_width(), rect.get_y()+0.5*rect.get_height(),
             '%d' % int(width),
             ha='center', va='center')
# plt.bar_label(splot.containers[0],size=16,label_type='center')
# plt.savefig("add_annotation_to_bars_in_barplot_Seaborn_Python.png")

# %%
all_.dropna(inplace = True)

# %%
sns.distplot(all_, color='#DE9C10')
plt.xlabel("Share (%)", size=14)
plt.yticks([])
plt.title('Distrbituion of female STEM graduates (International)')
# Out:
# Text(0.5, 1.0, 'Distrbituion of female STEM graduates (International)')

# %% [markdown]
# - There are fewer female than male STEM graduates in 107 of 114 Economies
# - Fewer than 4 of Every 10 STEM Graduates are Females

# %% [markdown]
# - What are the incomes of STEM majors in these countries
# - Does income explain immigration rates ?

# %% [markdown]
# ### Countries that contrbute most to STEM

# %%
stem_actors = ['Portugal ', 'Austria ', 'Estonia', 'Greece', 'France', 
              'Finland', 'Sweden', 'Germany', 'Canada', 'South Korea']
# transfer of knowledge 
stem[stem.index.isin(stem_actors)]
# Out:
#                   1999      2000      2001      2002      2003      2004  \
# Country Name
# Canada        61.33005  28.88889  17.07317  12.55061  51.21951  11.29666
# Estonia       14.41441  22.15569  32.53589  21.75926  24.70588  28.20513
# Finland       35.08260  40.38610  39.54023  42.35294  40.84589  42.91915
# France        35.08260  17.48784  39.54023  20.74563  21.68467  17.18799
# Germany       11.68676  10.64075  12.36967  11.33068  14.28571  41.66667
# Greece        11.68676  10.64075  12.36967  11.33068  14.28571  32.16595
# Sweden        34.26160  44.74560  40.71534  41.90519  40.16288  35.28148
#
#                   2005      2006      2007      2008      2009      2010  \
# Country Name
# Canada        46.96970  71.73913  10.43277   9.09894  45.00434  28.36879
# Estonia       26.44628  29.96454  22.23859  23.58318  24.55446  25.89928
# Finland       25.03987  29.96454  22.23859  21.89781  26.97368  28.39952
# ...

# %% [markdown]
# ## Migrant

# %% [markdown]
# ###

# %%
migrant = pd.read_csv('data/female_migrant_region.csv')
migrant.head()
# Out:
#                  Country Name       1995       2000       2005       2010  \
# 0         East Asia & Pacific  48.963828  49.159132  44.923797  42.804523
# 1       Europe & Central Asia  52.232010  52.348771  52.315734  52.431162
# 2   Latin America & Caribbean  48.938679  48.972331  48.783136  48.378833
# 3  Middle East & North Africa  44.416632  44.129095  43.302207  43.352646
# 4               North America  50.767140  50.420904  50.232079  51.021421
#
#         2019
# 0  41.444771
# 1  51.207344
# 2  48.563857
# 3  45.065849
# 4  51.741974

# %%
migrant['Country Name'].unique()
# Out:
# array(['East Asia & Pacific', 'Europe & Central Asia',
#        'Latin America & Caribbean', 'Middle East & North Africa',
#        'North America', 'South Asia', 'Sub-Saharan Africa'], dtype=object)

# %%
# regions = ['Latin America & Caribbean', 'South Asia', 'Sub-Saharan Africa',
#            'Europe & Central Asia', 'Middle East & North Africa',
#            'East Asia & Pacific', 'North America'],
# migrant = migrant[~migrant['Country Name'].isin(regions)]
migrant.head()
# Out:
#                  Country Name       1995       2000       2005       2010  \
# 0         East Asia & Pacific  48.963828  49.159132  44.923797  42.804523
# 1       Europe & Central Asia  52.232010  52.348771  52.315734  52.431162
# 2   Latin America & Caribbean  48.938679  48.972331  48.783136  48.378833
# 3  Middle East & North Africa  44.416632  44.129095  43.302207  43.352646
# 4               North America  50.767140  50.420904  50.232079  51.021421
#
#         2019
# 0  41.444771
# 1  51.207344
# 2  48.563857
# 3  45.065849
# 4  51.741974

# %%
# migrant.mean(axis = 0)
migrant_mean = pd.DataFrame(migrant.mean(axis = 0), columns = ['Percentage'])

# %%
migrant_mean
# Out:
#       Percentage
# 1995   48.607984
# 2000   48.640156
# 2005   47.765270
# 2010   47.704837
# 2019   47.897641

# %%
# boxplot
plt.figure(figsize=(12, 8))
splot = sns.barplot(x = migrant_mean.index, y = 'Percentage', data=migrant_mean, color = 'gold')
plt.xlabel("Year", size=14)
# plt.xticks([])
plt.ylabel("Mean Share", size=14)
plt.title('Mean Share of Female Migrants', size = 16)
for rect in splot.patches:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2., height,
            '%.1f' % float(height),
            ha='center', va='bottom', size = 12)
# for p in splot.patches:
#     splot.annotate(format(p.get_height(), '.1f'), 
#                    (p.get_x() + p.get_width() / 2., p.get_height()), 
#                    ha = 'center', va = 'center', 
#                    size=15,
#                    xytext = (0, -12), 
#                    textcoords = 'offset points')
# plt.savefig("share_of_female_migrants.png")

# %% [markdown]
# ###

# %%
regions = ['Latin America & Caribbean', 'South Asia', 'Sub-Saharan Africa',
           'Europe & Central Asia', 'Middle East & North Africa',
           'East Asia & Pacific', 'North America']
region_df = migrant.copy()
# region_df.reset_index(inplace = True, drop = True),
region_df
# Out:
#                  Country Name       1995       2000       2005       2010  \
# 0         East Asia & Pacific  48.963828  49.159132  44.923797  42.804523
# 1       Europe & Central Asia  52.232010  52.348771  52.315734  52.431162
# 2   Latin America & Caribbean  48.938679  48.972331  48.783136  48.378833
# 3  Middle East & North Africa  44.416632  44.129095  43.302207  43.352646
# 4               North America  50.767140  50.420904  50.232079  51.021421
# 5                  South Asia  48.032828  48.211087  48.317031  48.614689
# 6          Sub-Saharan Africa  46.904775  47.239774  46.482903  47.330586
#
#         2019
# 0  41.444771
# 1  51.207344
# 2  48.563857
# 3  45.065849
# 4  51.741974
# 5  48.946274
# 6  48.313416

# %%
region_df = region_df.melt(id_vars=['Country Name'],
                   var_name='Year',
                   value_name='Percentage')

# %%
region_df
# Out:
#                   Country Name  Year  Percentage
# 0          East Asia & Pacific  1995   48.963828
# 1        Europe & Central Asia  1995   52.232010
# 2    Latin America & Caribbean  1995   48.938679
# 3   Middle East & North Africa  1995   44.416632
# 4                North America  1995   50.767140
# 5                   South Asia  1995   48.032828
# 6           Sub-Saharan Africa  1995   46.904775
# 7          East Asia & Pacific  2000   49.159132
# 8        Europe & Central Asia  2000   52.348771
# 9    Latin America & Caribbean  2000   48.972331
# 10  Middle East & North Africa  2000   44.129095
# 11               North America  2000   50.420904
# 12                  South Asia  2000   48.211087
# 13          Sub-Saharan Africa  2000   47.239774
# 14         East Asia & Pacific  2005   44.923797
# 15       Europe & Central Asia  2005   52.315734
# 16   Latin America & Caribbean  2005   48.783136
# 17  Middle East & North Africa  2005   43.302207
# ...

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(data = region_df, x = 'Year', y = 'Percentage', hue = 'Country Name')
plt.xlabel("Year", size=14)
# plt.xticks([])
plt.ylabel("Share (%)", size=14)
plt.title('Percentage of Female Migrants by region', size = 16)
plt.legend(bbox_to_anchor=(1, 1), loc="upper left")
# plt.savefig("female_migrants_by_region.png")
# Out:
# (<matplotlib.legend.Legend at 0x1a3dbb977f0>,)

# %% [markdown]
# In comparison to males ???,
# - TODO: Rename country name to Region...

# %%
income_df = pd.read_csv('data/female_migrant_income.csv')
income_df
# Out:
#           1995       2000       2005       2010       2019  \
# 0    45.324516  43.559414  43.557847  43.558672  49.937901
# 1    53.353701  53.073864  49.036902  49.035693  49.035801
# 2    45.160896  45.160929  45.160114  47.121642  47.166115
# 3    47.887263  48.225755  48.425700  48.639355  48.969795
# 4    46.640728  47.581085  47.381606  47.578430  48.802714
# 5    47.868787  49.321159  50.692168  51.742712  48.957473
# 6    54.153846  55.285857  55.329211  55.368772  55.401102
# 7    52.790318  53.388187  53.689824  53.947076  53.970687
# 8    58.934379  58.934489  59.199905  59.426845  58.981168
# 9    55.221334  55.092347  55.258144  55.396627  55.395270
# 10   49.599960  50.073525  50.406414  50.330785  50.399999
# 11   52.698032  52.002465  52.157674  52.278854  50.921001
# 12   56.546924  56.902668  55.219377  53.228049  52.088921
# 13   47.494787  46.743842  48.139050  49.068255  49.423462
# 14   29.979755  30.922748  28.564074  27.658181  27.717729
# ...

# %%
income_df = income_df.groupby('IncomeGroup').mean()
# income_df
income_df.reset_index(inplace = True)

# %%
income_df = income_df.melt(id_vars='IncomeGroup',
                   var_name='Year',
                   value_name='Percentage')

# %%
income_df
# Out:
#             IncomeGroup  Year  Percentage
# 0           High income  1995   48.854764
# 1            Low income  1995   48.333966
# 2   Lower middle income  1995   48.196623
# 3   Upper middle income  1995   49.003355
# 4           High income  2000   49.108851
# 5            Low income  2000   48.491058
# 6   Lower middle income  2000   48.255776
# 7   Upper middle income  2000   48.893375
# 8           High income  2005   48.839134
# 9            Low income  2005   48.840449
# 10  Lower middle income  2005   47.408617
# 11  Upper middle income  2005   48.328993
# 12          High income  2010   48.562538
# 13           Low income  2010   48.879341
# 14  Lower middle income  2010   47.531132
# 15  Upper middle income  2010   47.982199
# 16          High income  2019   48.431782
# 17           Low income  2019   49.017372
# 18  Lower middle income  2019   47.557339
# 19  Upper middle income  2019   47.132380

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(data = income_df, x = 'Year', y = 'Percentage', hue = 'IncomeGroup', palette = 'vlag')
plt.xlabel("Year", size=14)
plt.ylabel("Mean Share (%)", size=14)
plt.title('Percentage of Female Migrants by Income', size = 16)
plt.legend(bbox_to_anchor=(1, 1), loc="upper left")
# plt.savefig("female_migrants_by_income.png")

# %% [markdown]
# ### Gender Inequality Index
